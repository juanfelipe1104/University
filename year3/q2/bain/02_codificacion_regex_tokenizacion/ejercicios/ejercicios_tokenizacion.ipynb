# %% [markdown]
# # Ejercicios: Tokenización, Part Of Speech, Lematización, WordCloud
# Procesar los textos siguientes siguiendo los pasos indicados al final.

# %% [markdown]
# ## Texto (Noticia):
# The government has announced new measures to combat climate change. These measures include reducing carbon emissions and promoting renewable energy sources. The initiative aims to achieve net-zero emissions by 2050. Experts believe that these steps are crucial for the sustainability of our planet. The public is encouraged to participate in various programs to support this cause.

# %% [markdown]
# ## Texto (Twitter):
# Just watched an amazing football match! ⚽️ #Sports #Football @TeamA
#
# Can't believe how good the game was last night! #Exciting @TeamB
#
# The team played exceptionally well and deserved the win. #Victory 🏆
#
# Feeling inspired after that match! #Motivation #SportsLife
#
# What a goal by @Player1! Absolutely stunning! #GoalOfTheSeason

# %% [markdown]
# ## Texto (Reseña de producto):
# This phone is absolutely    fantastic . . . The camera quality is outstanding , and the battery life lasts all day . . . The screen is bright and clear!!! >.< ,                    making it perfect for watching videos . . . The performance is smooth and fast , even with multiple apps running . . . Highly recommended for anyone looking for a new smartphone . . . The design is sleek and modern , and the build quality is top - notch . . . Customer service was also very helpful when I had questions about the features . . .  :DD

# %% [markdown]
# ## Texto (Blog):
# Today, we are going to discuss the importance of daily meditation. Meditation can help reduce stress and improve concentration. By setting aside just a few minutes each day, you can experience significant benefits. Regular practice can lead to a calmer mind and a more focused outlook on life. Start your meditation journey today and see the positive changes it brings. Many people find that meditation helps them to be more present and mindful in their daily activities. It can also improve sleep quality and overall well-being.

# %% [markdown]
# ## Texto (Conversación de WhatsApp):
# Alice: Hey, are we still on for dinner tonight ? ?
#
# Bob: Yes, definitely ! ! What time should we meet ?
#
# Alice: How about 7 PM at the new Italian place downtown ?
#
# Bob: Sounds perfect ! I've heard great things about their pasta . . .
#
# Alice: Me too ! ! Can't wait to try it . . . See you there !
#
# Bob: See you ! 😊

# %% [markdown]
# ## Pasos de Procesamiento:
# 1. Limpieza y normalización del texto: Eliminar espacios extras y signos de puntuación incorrectos.
# 2. Tokenización del texto: Dividir el texto en palabras individuales.
# 3. Eliminación de stop words: Filtrar palabras comunes que no aportan mucho significado.
# 4. Extracción del Part-of-Speech (POS): Etiquetar cada palabra con su categoría gramatical y añadirlo como columna en el DataFrame.
# 5. Lematización de las palabras y añadirlas como columna en el DataFrame.
# 6. Extracción de palabras especiales: Crear un nuevo DataFrame con emoticonos, hashtags, referencias, fechas, horas, etc.
# 7. Mostrar un WordCloud: Generar una nube de palabras basada en la frecuencia de las palabras (después de eliminar stop words).

# %% [markdown]
# # Codigo

# %%
#General Imports
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
nltk.download("punkt_tab")
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/juan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/juan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/juan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/juan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## Codigo Texto (Noticia)

# %%
# Texto
texto = """
The government has announced new measures to combat climate change. These measures include reducing carbon emissions and promoting renewable energy sources. The initiative aims to achieve net-zero emissions by 2050. Experts believe that these steps are crucial for the sustainability of our planet. The public is encouraged to participate in various programs to support this cause.
"""

# 1. Limpieza y normalización del texto

texto = re.sub(r'[^\w\s]', '', texto).strip().lower()
print(texto)

# 2. Tokenización del texto

tokens = word_tokenize(texto)
print("Tokens: ")
print(tokens)

# 3. Eliminación de stop words

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tokens_sin_stopwords = [word for word in tokens if word not in stop_words]
print("Tokens sin stopwords: ")
print(tokens_sin_stopwords)

# 4. Extracción del Part-of-Speech (POS)

pos_tags = pos_tag(tokens_sin_stopwords)
print("Part of Speech Tags: ")
print(pos_tags)

# 5. Lematización de las palabras y mostrar el DataFrame

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens_sin_stopwords]
df_lemmatized = pd.DataFrame({
    'Original': tokens_sin_stopwords,
    'Lematizado': lemmatized_words
})
display(df_lemmatized)

# 6. Extracción de palabras especiales y mostrar el DataFrame
special_words = [word for word, pos in pos_tags if pos.startswith('NN') or pos.startswith('VB')]
df_special = pd.DataFrame({
    'Palabra Especial': special_words
})
display(df_special)

# 7. Mostrar un WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(special_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /home/juan/nltk_data...
# the government has announced new measures to combat climate change these measures include reducing carbon emissions and promoting renewable energy sources the initiative aims to achieve netzero emissions by 2050 experts believe that these steps are crucial for the sustainability of our planet the public is encouraged to participate in various programs to support this cause
# Tokens:
# ['the', 'government', 'has', 'announced', 'new', 'measures', 'to', 'combat', 'climate', 'change', 'these', 'measures', 'include', 'reducing', 'carbon', 'emissions', 'and', 'promoting', 'renewable', 'energy', 'sources', 'the', 'initiative', 'aims', 'to', 'achieve', 'netzero', 'emissions', 'by', '2050', 'experts', 'believe', 'that', 'these', 'steps', 'are', 'crucial', 'for', 'the', 'sustainability', 'of', 'our', 'planet', 'the', 'public', 'is', 'encouraged', 'to', 'participate', 'in', 'various', 'programs', 'to', 'support', 'this', 'cause']
# Tokens sin stopwords:
# ['government', 'announced', 'new', 'measures', 'combat', 'climate', 'change', 'measures', 'include', 'reducing', 'carbon', 'emissions', 'promoting', 'renewable', 'energy', 'sources', 'initiative', 'aims', 'achieve', 'netzero', 'emissions', '2050', 'experts', 'believe', 'steps', 'crucial', 'sustainability', 'planet', 'public', 'encouraged', 'participate', 'various', 'programs', 'support', 'cause']
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Part of Speech Tags:
# [('government', 'NN'), ('announced', 'VBD'), ('new', 'JJ'), ('measures', 'NNS'), ('combat', 'VBP'), ('climate', 'NN'), ('change', 'NN'), ('measures', 'NNS'), ('include', 'VBP'), ('reducing', 'VBG'), ('carbon', 'NN'), ('emissions', 'NNS'), ('promoting', 'VBG'), ('renewable', 'JJ'), ('energy', 'NN'), ('sources', 'NNS'), ('initiative', 'VBP'), ('aims', 'NNS'), ('achieve', 'VBP'), ('netzero', 'CD'), ('emissions', 'NNS'), ('2050', 'CD'), ('experts', 'NNS'), ('believe', 'VBP'), ('steps', 'NNS'), ('crucial', 'JJ'), ('sustainability', 'NN'), ('planet', 'VBZ'), ('public', 'JJ'), ('encouraged', 'VBN'), ('participate', 'VBP'), ('various', 'JJ'), ('programs', 'NNS'), ('support', 'NN'), ('cause', 'NN')]
#           Original      Lematizado
# 0       government      government
# 1        announced       announced
# 2              new             new
# 3         measures         measure
# 4           combat          combat
# 5          climate         climate
# 6           change          change
# 7         measures         measure
# 8          include         include
# 9         reducing        reducing
# 10          carbon          carbon
# 11       emissions        emission
# 12       promoting       promoting
# 13       renewable       renewable
# 14          energy          energy
# 15         sources          source
# 16      initiative      initiative
# 17            aims             aim
# 18         achieve         achieve
# 19         netzero         netzero
# 20       emissions        emission
# 21            2050            2050
# 22         experts          expert
# 23         believe         believe
# 24           steps            step
# 25         crucial         crucial
# 26  sustainability  sustainability
# 27          planet          planet
# 28          public          public
# 29      encouraged      encouraged
# 30     participate     participate
# 31         various         various
# 32        programs         program
# 33         support         support
# 34           cause           cause
#    Palabra Especial
# 0        government
# 1         announced
# 2          measures
# 3            combat
# 4           climate
# 5            change
# 6          measures
# 7           include
# 8          reducing
# 9            carbon
# 10        emissions
# 11        promoting
# 12           energy
# 13          sources
# 14       initiative
# 15             aims
# 16          achieve
# 17        emissions
# 18          experts
# 19          believe
# 20            steps
# 21   sustainability
# 22           planet
# 23       encouraged
# 24      participate
# 25         programs
# 26          support
# 27            cause

# %% [markdown]
# ## Codigo Texto (Twitter)

# %%
# Texto
texto = """
Just watched an amazing football match! ⚽️ #Sports #Football @TeamA
Can't believe how good the game was last night! #Exciting @TeamB
The team played exceptionally well and deserved the win. #Victory 🏆
Feeling inspired after that match! #Motivation #SportsLife
What a goal by @Player1! Absolutely stunning! #GoalOfTheSeason
"""

# 1. Limpieza y normalización del texto

texto = re.sub(r'[^\w\s]', '', texto).strip().lower()
print(texto)

# 2. Tokenización del texto

tokens = word_tokenize(texto)
print("Tokens: ")
print(tokens)

# 3. Eliminación de stop words

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tokens_sin_stopwords = [word for word in tokens if word not in stop_words]
print("Tokens sin stopwords: ")
print(tokens_sin_stopwords)

# 4. Extracción del Part-of-Speech (POS)

pos_tags = pos_tag(tokens_sin_stopwords)
print("Part of Speech Tags: ")
print(pos_tags)

# 5. Lematización de las palabras y mostrar el DataFrame

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens_sin_stopwords]
df_lemmatized = pd.DataFrame({
    'Original': tokens_sin_stopwords,
    'Lematizado': lemmatized_words
})
display(df_lemmatized)

# 6. Extracción de palabras especiales y mostrar el DataFrame
special_words = [word for word, pos in pos_tags if pos.startswith('NN') or pos.startswith('VB')]
df_special = pd.DataFrame({
    'Palabra Especial': special_words
})
display(df_special)

# 7. Mostrar un WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(special_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# just watched an amazing football match  sports football teama
# cant believe how good the game was last night exciting teamb
# the team played exceptionally well and deserved the win victory
# feeling inspired after that match motivation sportslife
# what a goal by player1 absolutely stunning goaloftheseason
# Tokens:
# ['just', 'watched', 'an', 'amazing', 'football', 'match', 'sports', 'football', 'teama', 'cant', 'believe', 'how', 'good', 'the', 'game', 'was', 'last', 'night', 'exciting', 'teamb', 'the', 'team', 'played', 'exceptionally', 'well', 'and', 'deserved', 'the', 'win', 'victory', 'feeling', 'inspired', 'after', 'that', 'match', 'motivation', 'sportslife', 'what', 'a', 'goal', 'by', 'player1', 'absolutely', 'stunning', 'goaloftheseason']
# Tokens sin stopwords:
# ['watched', 'amazing', 'football', 'match', 'sports', 'football', 'teama', 'cant', 'believe', 'good', 'game', 'last', 'night', 'exciting', 'teamb', 'team', 'played', 'exceptionally', 'well', 'deserved', 'win', 'victory', 'feeling', 'inspired', 'match', 'motivation', 'sportslife', 'goal', 'player1', 'absolutely', 'stunning', 'goaloftheseason']
# Part of Speech Tags:
# [('watched', 'VBN'), ('amazing', 'VBG'), ('football', 'NN'), ('match', 'NN'), ('sports', 'NNS'), ('football', 'NN'), ('teama', 'NN'), ('cant', 'NN'), ('believe', 'VBP'), ('good', 'JJ'), ('game', 'NN'), ('last', 'JJ'), ('night', 'NN'), ('exciting', 'VBG'), ('teamb', 'NN'), ('team', 'NN'), ('played', 'VBD'), ('exceptionally', 'RB'), ('well', 'RB'), ('deserved', 'JJ'), ('win', 'VBP'), ('victory', 'NN'), ('feeling', 'NN'), ('inspired', 'VBD'), ('match', 'JJ'), ('motivation', 'NN'), ('sportslife', 'NN'), ('goal', 'NN'), ('player1', 'NN'), ('absolutely', 'RB'), ('stunning', 'VBG'), ('goaloftheseason', 'NN')]
# [nltk_data] Downloading package stopwords to /home/juan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#            Original       Lematizado
# 0           watched          watched
# 1           amazing          amazing
# 2          football         football
# 3             match            match
# 4            sports            sport
# 5          football         football
# 6             teama            teama
# 7              cant             cant
# 8           believe          believe
# 9              good             good
# 10             game             game
# 11             last             last
# 12            night            night
# 13         exciting         exciting
# 14            teamb            teamb
# 15             team             team
# 16           played           played
# 17    exceptionally    exceptionally
# 18             well             well
# 19         deserved         deserved
# 20              win              win
# 21          victory          victory
# 22          feeling          feeling
# 23         inspired         inspired
# 24            match            match
# 25       motivation       motivation
# 26       sportslife       sportslife
# 27             goal             goal
# 28          player1          player1
# 29       absolutely       absolutely
# 30         stunning         stunning
# 31  goaloftheseason  goaloftheseason
#    Palabra Especial
# 0           watched
# 1           amazing
# 2          football
# 3             match
# 4            sports
# 5          football
# 6             teama
# 7              cant
# 8           believe
# 9              game
# 10            night
# 11         exciting
# 12            teamb
# 13             team
# 14           played
# 15              win
# 16          victory
# 17          feeling
# 18         inspired
# 19       motivation
# 20       sportslife
# 21             goal
# 22          player1
# 23         stunning
# 24  goaloftheseason

# %% [markdown]
# ## Codigo Texto (Reseña de producto)

# %%
# Texto
texto = """
This phone is absolutely fantastic . . . The camera quality is outstanding , and the battery life lasts all day . . . The screen is bright and clear!!! >.< , making it perfect for watching videos . . . The performance is smooth and fast , even with multiple apps running . . . Highly recommended for anyone looking for a new smartphone . . . The design is sleek and modern , and the build quality is top - notch . . . Customer service was also very helpful when I had questions about the features . . . :DD
"""

# 1. Limpieza y normalización del texto

texto = re.sub(r'[^\w\s]', '', texto).strip().lower()
print(texto)

# 2. Tokenización del texto

tokens = word_tokenize(texto)
print("Tokens: ")
print(tokens)

# 3. Eliminación de stop words

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tokens_sin_stopwords = [word for word in tokens if word not in stop_words]
print("Tokens sin stopwords: ")
print(tokens_sin_stopwords)

# 4. Extracción del Part-of-Speech (POS)

pos_tags = pos_tag(tokens_sin_stopwords)
print("Part of Speech Tags: ")
print(pos_tags)

# 5. Lematización de las palabras y mostrar el DataFrame

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens_sin_stopwords]
df_lemmatized = pd.DataFrame({
    'Original': tokens_sin_stopwords,
    'Lematizado': lemmatized_words
})
display(df_lemmatized)

# 6. Extracción de palabras especiales y mostrar el DataFrame
special_words = [word for word, pos in pos_tags if pos.startswith('NN') or pos.startswith('VB')]
df_special = pd.DataFrame({
    'Palabra Especial': special_words
})
display(df_special)

# 7. Mostrar un WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(special_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# this phone is absolutely fantastic    the camera quality is outstanding  and the battery life lasts all day    the screen is bright and clear   making it perfect for watching videos    the performance is smooth and fast  even with multiple apps running    highly recommended for anyone looking for a new smartphone    the design is sleek and modern  and the build quality is top  notch    customer service was also very helpful when i had questions about the features    dd
# Tokens:
# ['this', 'phone', 'is', 'absolutely', 'fantastic', 'the', 'camera', 'quality', 'is', 'outstanding', 'and', 'the', 'battery', 'life', 'lasts', 'all', 'day', 'the', 'screen', 'is', 'bright', 'and', 'clear', 'making', 'it', 'perfect', 'for', 'watching', 'videos', 'the', 'performance', 'is', 'smooth', 'and', 'fast', 'even', 'with', 'multiple', 'apps', 'running', 'highly', 'recommended', 'for', 'anyone', 'looking', 'for', 'a', 'new', 'smartphone', 'the', 'design', 'is', 'sleek', 'and', 'modern', 'and', 'the', 'build', 'quality', 'is', 'top', 'notch', 'customer', 'service', 'was', 'also', 'very', 'helpful', 'when', 'i', 'had', 'questions', 'about', 'the', 'features', 'dd']
# Tokens sin stopwords:
# ['phone', 'absolutely', 'fantastic', 'camera', 'quality', 'outstanding', 'battery', 'life', 'lasts', 'day', 'screen', 'bright', 'clear', 'making', 'perfect', 'watching', 'videos', 'performance', 'smooth', 'fast', 'even', 'multiple', 'apps', 'running', 'highly', 'recommended', 'anyone', 'looking', 'new', 'smartphone', 'design', 'sleek', 'modern', 'build', 'quality', 'top', 'notch', 'customer', 'service', 'also', 'helpful', 'questions', 'features', 'dd']
# Part of Speech Tags:
# [('phone', 'NN'), ('absolutely', 'RB'), ('fantastic', 'JJ'), ('camera', 'NN'), ('quality', 'NN'), ('outstanding', 'JJ'), ('battery', 'NN'), ('life', 'NN'), ('lasts', 'VBZ'), ('day', 'NN'), ('screen', 'JJ'), ('bright', 'JJ'), ('clear', 'JJ'), ('making', 'VBG'), ('perfect', 'JJ'), ('watching', 'VBG'), ('videos', 'JJ'), ('performance', 'NN'), ('smooth', 'VBD'), ('fast', 'RB'), ('even', 'RB'), ('multiple', 'JJ'), ('apps', 'IN'), ('running', 'VBG'), ('highly', 'RB'), ('recommended', 'VBN'), ('anyone', 'NN'), ('looking', 'VBG'), ('new', 'JJ'), ('smartphone', 'NN'), ('design', 'NN'), ('sleek', 'JJ'), ('modern', 'JJ'), ('build', 'JJ'), ('quality', 'NN'), ('top', 'JJ'), ('notch', 'NN'), ('customer', 'NN'), ('service', 'NN'), ('also', 'RB'), ('helpful', 'JJ'), ('questions', 'NNS'), ('features', 'NNS'), ('dd', 'VBP')]
# [nltk_data] Downloading package stopwords to /home/juan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#        Original   Lematizado
# 0         phone        phone
# 1    absolutely   absolutely
# 2     fantastic    fantastic
# 3        camera       camera
# 4       quality      quality
# 5   outstanding  outstanding
# 6       battery      battery
# 7          life         life
# 8         lasts         last
# 9           day          day
# 10       screen       screen
# 11       bright       bright
# 12        clear        clear
# 13       making       making
# 14      perfect      perfect
# 15     watching     watching
# 16       videos        video
# 17  performance  performance
# 18       smooth       smooth
# 19         fast         fast
# 20         even         even
# 21     multiple     multiple
# 22         apps         apps
# 23      running      running
# 24       highly       highly
# 25  recommended  recommended
# 26       anyone       anyone
# 27      looking      looking
# 28          new          new
# 29   smartphone   smartphone
# 30       design       design
# 31        sleek        sleek
# 32       modern       modern
# 33        build        build
# 34      quality      quality
# 35          top          top
# 36        notch        notch
# 37     customer     customer
# 38      service      service
# 39         also         also
# 40      helpful      helpful
# 41    questions     question
# 42     features      feature
# 43           dd           dd
#    Palabra Especial
# 0             phone
# 1            camera
# 2           quality
# 3           battery
# 4              life
# 5             lasts
# 6               day
# 7            making
# 8          watching
# 9       performance
# 10           smooth
# 11          running
# 12      recommended
# 13           anyone
# 14          looking
# 15       smartphone
# 16           design
# 17          quality
# 18            notch
# 19         customer
# 20          service
# 21        questions
# 22         features
# 23               dd

# %% [markdown]
# ## Codigo Texto (Blog)

# %%
# Texto
texto = """
Today, we are going to discuss the importance of daily meditation. Meditation can help reduce stress and improve concentration. By setting aside just a few minutes each day, you can experience significant benefits. Regular practice can lead to a calmer mind and a more focused outlook on life. Start your meditation journey today and see the positive changes it brings. Many people find that meditation helps them to be more present and mindful in their daily activities. It can also improve sleep quality and overall well-being.
"""

# 1. Limpieza y normalización del texto

texto = re.sub(r'[^\w\s]', '', texto).strip().lower()
print(texto)

# 2. Tokenización del texto

tokens = word_tokenize(texto)
print("Tokens: ")
print(tokens)

# 3. Eliminación de stop words

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tokens_sin_stopwords = [word for word in tokens if word not in stop_words]
print("Tokens sin stopwords: ")
print(tokens_sin_stopwords)

# 4. Extracción del Part-of-Speech (POS)

pos_tags = pos_tag(tokens_sin_stopwords)
print("Part of Speech Tags: ")
print(pos_tags)

# 5. Lematización de las palabras y mostrar el DataFrame

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens_sin_stopwords]
df_lemmatized = pd.DataFrame({
    'Original': tokens_sin_stopwords,
    'Lematizado': lemmatized_words
})
display(df_lemmatized)

# 6. Extracción de palabras especiales y mostrar el DataFrame
special_words = [word for word, pos in pos_tags if pos.startswith('NN') or pos.startswith('VB')]
df_special = pd.DataFrame({
    'Palabra Especial': special_words
})
display(df_special)

# 7. Mostrar un WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(special_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# today we are going to discuss the importance of daily meditation meditation can help reduce stress and improve concentration by setting aside just a few minutes each day you can experience significant benefits regular practice can lead to a calmer mind and a more focused outlook on life start your meditation journey today and see the positive changes it brings many people find that meditation helps them to be more present and mindful in their daily activities it can also improve sleep quality and overall wellbeing
# Tokens:
# ['today', 'we', 'are', 'going', 'to', 'discuss', 'the', 'importance', 'of', 'daily', 'meditation', 'meditation', 'can', 'help', 'reduce', 'stress', 'and', 'improve', 'concentration', 'by', 'setting', 'aside', 'just', 'a', 'few', 'minutes', 'each', 'day', 'you', 'can', 'experience', 'significant', 'benefits', 'regular', 'practice', 'can', 'lead', 'to', 'a', 'calmer', 'mind', 'and', 'a', 'more', 'focused', 'outlook', 'on', 'life', 'start', 'your', 'meditation', 'journey', 'today', 'and', 'see', 'the', 'positive', 'changes', 'it', 'brings', 'many', 'people', 'find', 'that', 'meditation', 'helps', 'them', 'to', 'be', 'more', 'present', 'and', 'mindful', 'in', 'their', 'daily', 'activities', 'it', 'can', 'also', 'improve', 'sleep', 'quality', 'and', 'overall', 'wellbeing']
# Tokens sin stopwords:
# ['today', 'going', 'discuss', 'importance', 'daily', 'meditation', 'meditation', 'help', 'reduce', 'stress', 'improve', 'concentration', 'setting', 'aside', 'minutes', 'day', 'experience', 'significant', 'benefits', 'regular', 'practice', 'lead', 'calmer', 'mind', 'focused', 'outlook', 'life', 'start', 'meditation', 'journey', 'today', 'see', 'positive', 'changes', 'brings', 'many', 'people', 'find', 'meditation', 'helps', 'present', 'mindful', 'daily', 'activities', 'also', 'improve', 'sleep', 'quality', 'overall', 'wellbeing']
# Part of Speech Tags:
# [('today', 'NN'), ('going', 'VBG'), ('discuss', 'JJ'), ('importance', 'NN'), ('daily', 'JJ'), ('meditation', 'NN'), ('meditation', 'NN'), ('help', 'NN'), ('reduce', 'VB'), ('stress', 'NN'), ('improve', 'VB'), ('concentration', 'NN'), ('setting', 'VBG'), ('aside', 'JJ'), ('minutes', 'NNS'), ('day', 'NN'), ('experience', 'NN'), ('significant', 'JJ'), ('benefits', 'NNS'), ('regular', 'JJ'), ('practice', 'NN'), ('lead', 'NN'), ('calmer', 'NN'), ('mind', 'NN'), ('focused', 'VBD'), ('outlook', 'NN'), ('life', 'NN'), ('start', 'VB'), ('meditation', 'NN'), ('journey', 'NN'), ('today', 'NN'), ('see', 'VBP'), ('positive', 'JJ'), ('changes', 'NNS'), ('brings', 'VBZ'), ('many', 'JJ'), ('people', 'NNS'), ('find', 'VBP'), ('meditation', 'NN'), ('helps', 'VBZ'), ('present', 'JJ'), ('mindful', 'JJ'), ('daily', 'JJ'), ('activities', 'NNS'), ('also', 'RB'), ('improve', 'VB'), ('sleep', 'NN'), ('quality', 'NN'), ('overall', 'JJ'), ('wellbeing', 'NN')]
# [nltk_data] Downloading package stopwords to /home/juan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#          Original     Lematizado
# 0           today          today
# 1           going          going
# 2         discuss         discus
# 3      importance     importance
# 4           daily          daily
# 5      meditation     meditation
# 6      meditation     meditation
# 7            help           help
# 8          reduce         reduce
# 9          stress         stress
# 10        improve        improve
# 11  concentration  concentration
# 12        setting        setting
# 13          aside          aside
# 14        minutes         minute
# 15            day            day
# 16     experience     experience
# 17    significant    significant
# 18       benefits        benefit
# 19        regular        regular
# 20       practice       practice
# 21           lead           lead
# 22         calmer         calmer
# 23           mind           mind
# 24        focused        focused
# 25        outlook        outlook
# 26           life           life
# 27          start          start
# 28     meditation     meditation
# 29        journey        journey
# 30          today          today
# 31            see            see
# 32       positive       positive
# 33        changes         change
# 34         brings         brings
# 35           many           many
# 36         people         people
# 37           find           find
# 38     meditation     meditation
# 39          helps           help
# 40        present        present
# 41        mindful        mindful
# 42          daily          daily
# 43     activities       activity
# 44           also           also
# 45        improve        improve
# 46          sleep          sleep
# 47        quality        quality
# 48        overall        overall
# 49      wellbeing      wellbeing
#    Palabra Especial
# 0             today
# 1             going
# 2        importance
# 3        meditation
# 4        meditation
# 5              help
# 6            reduce
# 7            stress
# 8           improve
# 9     concentration
# 10          setting
# 11          minutes
# 12              day
# 13       experience
# 14         benefits
# 15         practice
# 16             lead
# 17           calmer
# 18             mind
# 19          focused
# 20          outlook
# 21             life
# 22            start
# 23       meditation
# 24          journey
# 25            today
# 26              see
# 27          changes
# 28           brings
# 29           people
# 30             find
# 31       meditation
# 32            helps
# 33       activities
# 34          improve
# 35            sleep
# 36          quality
# 37        wellbeing

# %% [markdown]
# ## Codigo Texto (Conversación de WhatsApp)

# %%
# Texto
texto = """
Alice: Hey, are we still on for dinner tonight ? ?
Bob: Yes, definitely ! ! What time should we meet ?
Alice: How about 7 PM at the new Italian place downtown ?
Bob: Sounds perfect ! I've heard great things about their pasta . . .
Alice: Me too ! ! Can't wait to try it . . . See you there !
Bob: See you ! 😊
"""

# 1. Limpieza y normalización del texto

texto = re.sub(r'[^\w\s]', '', texto).strip().lower()
print(texto)

# 2. Tokenización del texto

tokens = word_tokenize(texto)
print("Tokens: ")
print(tokens)

# 3. Eliminación de stop words

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tokens_sin_stopwords = [word for word in tokens if word not in stop_words]
print("Tokens sin stopwords: ")
print(tokens_sin_stopwords)

# 4. Extracción del Part-of-Speech (POS)

pos_tags = pos_tag(tokens_sin_stopwords)
print("Part of Speech Tags: ")
print(pos_tags)

# 5. Lematización de las palabras y mostrar el DataFrame

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens_sin_stopwords]
df_lemmatized = pd.DataFrame({
    'Original': tokens_sin_stopwords,
    'Lematizado': lemmatized_words
})
display(df_lemmatized)

# 6. Extracción de palabras especiales y mostrar el DataFrame
special_words = [word for word, pos in pos_tags if pos.startswith('NN') or pos.startswith('VB')]
df_special = pd.DataFrame({
    'Palabra Especial': special_words
})
display(df_special)

# 7. Mostrar un WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(special_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# alice hey are we still on for dinner tonight
# bob yes definitely   what time should we meet
# alice how about 7 pm at the new italian place downtown
# bob sounds perfect  ive heard great things about their pasta
# alice me too   cant wait to try it    see you there
# bob see you
# Tokens:
# ['alice', 'hey', 'are', 'we', 'still', 'on', 'for', 'dinner', 'tonight', 'bob', 'yes', 'definitely', 'what', 'time', 'should', 'we', 'meet', 'alice', 'how', 'about', '7', 'pm', 'at', 'the', 'new', 'italian', 'place', 'downtown', 'bob', 'sounds', 'perfect', 'ive', 'heard', 'great', 'things', 'about', 'their', 'pasta', 'alice', 'me', 'too', 'cant', 'wait', 'to', 'try', 'it', 'see', 'you', 'there', 'bob', 'see', 'you']
# Tokens sin stopwords:
# ['alice', 'hey', 'still', 'dinner', 'tonight', 'bob', 'yes', 'definitely', 'time', 'meet', 'alice', '7', 'pm', 'new', 'italian', 'place', 'downtown', 'bob', 'sounds', 'perfect', 'ive', 'heard', 'great', 'things', 'pasta', 'alice', 'cant', 'wait', 'try', 'see', 'bob', 'see']
# Part of Speech Tags:
# [('alice', 'NN'), ('hey', 'NN'), ('still', 'RB'), ('dinner', 'VB'), ('tonight', 'JJ'), ('bob', 'NNS'), ('yes', 'RB'), ('definitely', 'RB'), ('time', 'NN'), ('meet', 'JJ'), ('alice', 'RB'), ('7', 'CD'), ('pm', 'JJ'), ('new', 'JJ'), ('italian', 'JJ'), ('place', 'NN'), ('downtown', 'NN'), ('bob', 'NN'), ('sounds', 'VBZ'), ('perfect', 'JJ'), ('ive', 'JJ'), ('heard', 'NN'), ('great', 'JJ'), ('things', 'NNS'), ('pasta', 'JJ'), ('alice', 'NN'), ('cant', 'NN'), ('wait', 'NN'), ('try', 'NN'), ('see', 'VBP'), ('bob', 'JJ'), ('see', 'VB')]
# [nltk_data] Downloading package stopwords to /home/juan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#       Original  Lematizado
# 0        alice       alice
# 1          hey         hey
# 2        still       still
# 3       dinner      dinner
# 4      tonight     tonight
# 5          bob         bob
# 6          yes         yes
# 7   definitely  definitely
# 8         time        time
# 9         meet        meet
# 10       alice       alice
# 11           7           7
# 12          pm          pm
# 13         new         new
# 14     italian     italian
# 15       place       place
# 16    downtown    downtown
# 17         bob         bob
# 18      sounds       sound
# 19     perfect     perfect
# 20         ive         ive
# 21       heard       heard
# 22       great       great
# 23      things       thing
# 24       pasta       pasta
# 25       alice       alice
# 26        cant        cant
# 27        wait        wait
# 28         try         try
# 29         see         see
# 30         bob         bob
# 31         see         see
#    Palabra Especial
# 0             alice
# 1               hey
# 2            dinner
# 3               bob
# 4              time
# 5             place
# 6          downtown
# 7               bob
# 8            sounds
# 9             heard
# 10           things
# 11            alice
# 12             cant
# 13             wait
# 14              try
# 15              see
# 16              see
